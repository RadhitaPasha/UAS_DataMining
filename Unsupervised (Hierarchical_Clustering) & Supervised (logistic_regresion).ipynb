# %% [markdown]
# <a href="https://colab.research.google.com/github/RadhitaPasha/UAS_DataMining/blob/main/Unsupervised%20(Hierarchical_Clustering)%20%26%20Supervised%20(logistic_regresion).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Unsupervised (Hierarchical Clustering)

# %%
# import library
from matplotlib import pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
import numpy as np

# %%
# buat array 2D ke dalam variabel x. Data ini yang akan kita klaster
x = np.array([[1,2],[2.5,4.5],[2,2],[4,1.5],[4,2.5]])

# %%
print(x)
# Out:
# [[1.  2. ]
#  [2.5 4.5]
#  [2.  2. ]
#  [4.  1.5]
#  [4.  2.5]]

# %%
# Melakukan hierarchical klastering
z = linkage(x)

# %%
print(z)
# Out:
# [[0.         2.         1.         2.        ]
#  [3.         4.         1.         2.        ]
#  [5.         6.         2.06155281 4.        ]
#  [1.         7.         2.5        5.        ]]

# %%
# Plot Dendogram
plt.figure(figsize=(25, 10))
plt.title('Dendogram Hierarchical Clustering')
plt.xlabel('data')
plt.ylabel('jarak')
dendrogram(z)
plt.show()

# %% [markdown]
# Supervised (logistic regresion)

# %%
import numpy as np
import matplotlib.pyplot as plt
#data kapasitas mobil
capacity = np.array([3,3,4,4,4,4,4,6,6,6])
#data harga mobil (dalam juta rupiah)
car_price = np.array([200, 215, 250, 250, 260, 275, 280, 350, 360, 375])
# %matplotlib inline
plt.scatter(capacity, car_price)

# %%
from ast import increment_lineno
import matplotlib.pyplot as plt
#data kapasitas mobil
capacity = np.array([3,3,4,4,4,4,4,6,6,6])
#data harga mobil (dalam juta rupiah)
car_price = np.array([200, 215, 250, 250, 260, 275, 280, 350, 360, 375])
# %matplotlib inline
plt.scatter(capacity, car_price)
from sklearn.linear_model import LinearRegression
capacity = capacity.reshape(-1, 1)
linreg = LinearRegression()

# %%
from ast import increment_lineno
import matplotlib.pyplot as plt
#data kapasitas mobil
capacity = np.array([3,3,4,4,4,4,4,6,6,6])
#data harga mobil (dalam juta rupiah)
car_price = np.array([200, 215, 250, 250, 260, 275, 280, 350, 360, 375])
# %matplotlib inline
plt.scatter(capacity, car_price)
from sklearn.linear_model import LinearRegression
capacity = capacity.reshape(-1, 1)
linreg = LinearRegression()
linreg.fit(capacity, car_price)
plt.scatter(capacity, car_price)
plt.plot(capacity, linreg.predict(capacity))
